# %% [markdown]
#  <h1> LOADING CSV FILE INTO A PANDAS DATAFRAME

# %%
import pandas as pd

d = pd.read_csv(r"01.Data Cleaning and Preprocessing.csv") 
df=pd.DataFrame(d)

print(df)
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 321     9-20:00    23.01    12.550      90.842  1188.517      289.826
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
# 323     9-22:00    25.75    13.417      85.451  1186.342      248.312
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %% [markdown]
# <h1>FILTERING DATA BASED ON CONDITIONS

# %%
df.loc[df['BlowFlow']<1400]
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 321     9-20:00    23.01    12.550      90.842  1188.517      289.826
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
# 323     9-22:00    25.75    13.417      85.451  1186.342      248.312
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
df.loc[(df["BlowFlow"]<1100) & (df["UCZAA"]<1.4)]
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 286    11-21:00    19.53    11.245      92.564  1040.922      384.977
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 286         342.79         284.633  1.368        444.58  ...        53.822
#
#      Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# 286        329.335         305.521      124.682       845.214       1301.95
#
#      WeakWashF   SteamHeatF-3   T-Top-Chips-4   SulphidityL-4
# 286     209.575         39.368         252.479             NaN
#
# [1 rows x 23 columns]

# %% [markdown]
# <h1>HANDLING MISSING VALUES

# %%
df
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 321     9-20:00    23.01    12.550      90.842  1188.517      289.826
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
# 323     9-22:00    25.75    13.417      85.451  1186.342      248.312
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
df.dropna()
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 5       1-08:00    14.23    15.350      85.518  1171.604      198.538
# 7      31-06:00    22.65    14.100      91.887  1307.852      288.989
# 9      31-08:00    24.70    13.850      96.208  1334.892      362.511
# ..          ...      ...       ...         ...       ...          ...
# 312    31-10:00    24.40    14.117      85.998  1330.104      394.234
# 317     4-16:00    17.80    16.625      78.367  1276.082      202.744
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
df.fillna("MISSING")
# Out:
#     Observation  Y-Kappa ChipRate BF-CMratio  BlowFlow ChipLevel4   \
# 0      31-00:00    23.10    16.52    121.717  1177.607     169.805
# 1      31-01:00    27.60    16.81     79.022   1328.36     341.327
# 2      31-02:00    23.19   16.709     79.562  1329.407     239.161
# 3      31-03:00    23.60   16.478     81.011  1334.877     213.527
# 4      31-04:00    22.90   15.618     93.244  1334.168     243.131
# ..          ...      ...      ...        ...       ...         ...
# 319    10-16:00    23.75   12.667      93.45  1178.252     276.955
# 320     9-19:00    19.80   12.558     94.352  1184.119     297.071
# 321     9-20:00    23.01    12.55     90.842  1188.517     289.826
# 322     9-21:00    24.32   13.083      88.91  1192.879     318.006
# 323     9-22:00    25.75   13.417     85.451  1186.342     248.312
#
#     T-upperExt-2  T-lowerExt-2      UCZAA WhiteFlow-4   ... SteamFlow-4   \
# 0         358.282        329.545    1.443      599.253  ...       67.122
# ...

# %%
df.loc[:,['BlowFlow','UCZAA']].fillna(45)
# Out:
#      BlowFlow    UCZAA
# 0    1177.607    1.443
# 1     1328.36    1.549
# 2    1329.407      1.6
# 3    1334.877    1.604
# 4    1334.168  MISSING
# ..        ...      ...
# 319  1178.252    1.523
# 320  1184.119    1.451
# 321  1188.517    1.457
# 322  1192.879    1.523
# 323  1186.342    1.474
#
# [324 rows x 2 columns]

# %% [markdown]
# <h1>CALCULATING SUMMARY STATISTICS

# %%
df.count()
# Out:
# Observation        324
# Y-Kappa            324
# ChipRate           324
# BF-CMratio         324
# BlowFlow           324
# ChipLevel4         324
# T-upperExt-2       324
# T-lowerExt-2       324
# UCZAA              324
# WhiteFlow-4        324
# AAWhiteSt-4        324
# AA-Wood-4          324
# ChipMoisture-4     324
# SteamFlow-4        324
# Lower-HeatT-3      324
# Upper-HeatT-3      324
# ChipMass-4         324
# WeakLiquorF        324
# BlackFlow-2        324
# WeakWashF          324
# SteamHeatF-3       324
# T-Top-Chips-4      324
# SulphidityL-4      324
# dtype: int64

# %%
df["BlowFlow"].head(20)
# Out:
# 0     1177.607
# 1      1328.36
# 2     1329.407
# 3     1334.877
# 4     1334.168
# 5     1171.604
# 6     1243.688
# 7     1307.852
# 8       1346.9
# 9     1334.892
# 10     1351.24
# 11    1330.104
# 12    1334.255
# 13    1332.331
# 14    1284.386
# 15    1197.775
# 16    1203.375
# 17    1218.797
# 18    1204.489
# 19    1206.709
# Name: BlowFlow, dtype: object
